# %%
include("include.jl");
# Out:
# SystemError: opening file "/Users/abdulrahmanalswaidan/Desktop/Project-Repos/HMM-withJumps-WIP/data/include.jl": No such file or directory
#
# Stacktrace:
#  [1] include(mapexpr::Function, mod::Module, _path::String)
#    @ Base ./Base.jl:307
#  [2] top-level scope
#    @ In[1]:1
#  [3] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
data = MyOriginalPortfolioDataSet()

# %%
original_dataset = data["dataset"]

# %%
oos_data = MyOutOfSamplePortfolioDataSet

# %%
oos_dataset = oos_data["dataset"]
